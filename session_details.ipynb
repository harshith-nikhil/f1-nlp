# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import fastf1
from fastf1.core import *

# %%
from data_extraction import *

# %%
events2023=['Bahrain Grand Prix','Saudi Arabian Grand Prix','Australian Grand Prix',
            'Azerbaijan Grand Prix','Miami Grand Prix','Monaco Grand Prix','Spanish Grand Prix',
            'Canadian Grand Prix','Austrian Grand Prix','British Grand Prix','Hungarian Grand Prix',
            'Belgian Grand Prix','Dutch Grand Prix','Italian Grand Prix','Singapore Grand Prix',
            'Japanese Grand Prix','Qatar Grand Prix','United States Grand Prix','Mexico City Grand Prix',
            'São Paulo Grand Prix','Las Vegas Grand Prix','Abu Dhabi Grand Prix']

# %%
event_session = ['baharin23_R','saudi23_R','aust23_R', 'azer23_R','mia23_R','mon23_R','span23_R', 'can23_R','austria23_R','brit23_R','hung23_R',
            'bel23_R','dutch23_R','ita23_R','sing23_R','jap23_R','qat23_R','austin23_R','mex23_R', 'brazil23_R','vegas23_R', 'abu23_R']

# %%
sessions_dict={}

# %%
def get_all_race_sessions(session_name, events):
    for session_name, event in zip(session_name, events):
        sessions_dict[session_name] = get_session_data(2023, event, 'R')

# %%
get_all_race_sessions(event_session, events2023)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (2.33 GB) /Users/harshith.nikhil/Library/Caches/fastf1
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# ...

# %%
event_rr = ['baharin23_rr','saudi23_rr','aust23_rr', 'azer23_rr','mia23_rr','mon23_rr','span23_rr', 'can23_rr','austria23_rr','brit23_rr','hung23_rr',
            'bel23_rr','dutch23_rr','ita23_rr','sing23_rr','jap23_rr','qat23_rr','austin23_rr','mex23_rr', 'brazil23_rr','vegas23_rr', 'abu23_rr']

# %%
rr_dict={}

# %%
def get_all_race_results(results_name, events_session, sessions_dict):
    for result_name, event in zip(results_name, events_session):
        rr_dict[result_name] = preprocess_race_results(sessions_dict[event])

# %%
get_all_race_results(event_rr, event_session, sessions_dict)

# %%
def get_result_dict(events, rr_dict, rr_names):
    race_result_dict={}
    for event, rr_name in zip(events, rr_names):
        race_result_dict[(event, 2023)] = rr_dict[rr_name]
    return race_result_dict

# %%
race_result_dict=get_result_dict(events2023, rr_dict, event_rr)

# %%
save_all_races_to_jsonl(race_result_dict, filename="f123_race_results.jsonl")
# Out:
# Saved 22 races to jsonl/f123_race_results.jsonl
